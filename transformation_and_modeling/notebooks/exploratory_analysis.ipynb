# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd

df = pd.read_csv('/Users/pakshaljain/Desktop/ETL-Hackathon/transformation_and_modeling/data/bronze/sample_data.csv')
print(df.head())
